# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid

from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score, precision_score, f1_score
import scipy


# Leemos el archivo 

data_dir = "wdbc.data"
data = pandas.read_csv(data_dir,sep=",",header=None)
data
# Out:
#            0  1      2      3       4       5        6        7        8   \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#           9   ...      22     23      24      25       26       27      28  \
# 0    0.14710  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119
# 1    0.07017  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 2    0.12790  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 3    0.10520  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 4    0.10430  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# ..       ...  ...     ...    ...     ...     ...      ...      ...     ...
# 564  0.13890  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 565  0.09791  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 566  0.05302  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 567  0.15200  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 568  0.00000  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#          29      30       31
# 0    0.2654  0.4601  0.11890
# 1    0.1860  0.2750  0.08902
# 2    0.2430  0.3613  0.08758
# 3    0.2575  0.6638  0.17300
# 4    0.1625  0.2364  0.07678
# ..      ...     ...      ...
# 564  0.2216  0.2060  0.07115
# 565  0.1628  0.2572  0.06637
# 566  0.1418  0.2218  0.07820
# 567  0.2650  0.4087  0.12400
# 568  0.0000  0.2871  0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# # Reemplazamos las M's y las B's por 1s y 0s, asi eficientamos el trabajo

# %%
data[[1]]= data[[1]].replace({"M":0,"B":1}) 
Y = data[[1]]
X = data.drop([0,1],axis=1) #Borramos los ID's y BM, para quedarnos con los datos que definen el resultado
print(X)
# Out:
#         2      3       4       5        6        7        8        9       10  \
# 0    17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710  0.2419
# 1    20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017  0.1812
# 2    19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790  0.2069
# 3    11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520  0.2597
# 4    20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430  0.1809
# ..     ...    ...     ...     ...      ...      ...      ...      ...     ...
# 564  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890  0.1726
# 565  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791  0.1752
# 566  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302  0.1590
# 567  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200  0.2397
# 568   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000  0.1587
#
#           11  ...      22     23      24      25       26       27      28  \
# 0    0.07871  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119
# 1    0.05667  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 2    0.05999  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 3    0.09744  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 4    0.05883  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# ..       ...  ...     ...    ...     ...     ...      ...      ...     ...
# 564  0.05623  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 565  0.05533  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 566  0.05648  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 567  0.07016  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 568  0.05884  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#          29      30       31
# 0    0.2654  0.4601  0.11890
# 1    0.1860  0.2750  0.08902
# 2    0.2430  0.3613  0.08758
# 3    0.2575  0.6638  0.17300
# 4    0.1625  0.2364  0.07678
# ..      ...     ...      ...
# 564  0.2216  0.2060  0.07115
# 565  0.1628  0.2572  0.06637
# 566  0.1418  0.2218  0.07820
# 567  0.2650  0.4087  0.12400
# 568  0.0000  0.2871  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# # Modelo Kneighbors

# %% [markdown]
# ## Separamos los datos para el entrenamiento

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.3, random_state=42)
print('X',X.shape)
print('Xtrain',Xtrain.shape)
print('Xtest',Xtest.shape)

model = KNeighborsClassifier(n_neighbors=5)
model.fit(Xtrain,ytrain)
ypred = model.predict(Xtest)

print('accuracy',accuracy_score(ytest,ypred))
print('macro-precision:',precision_score(ytest,ypred,average='macro'))
print('macro-recall:',recall_score(ytest,ypred,average='macro'))
print('macro-f1:',f1_score(ytest,ypred,average='macro'))
# Out:
# X (569, 30)
# Xtrain (398, 30)
# Xtest (171, 30)
# accuracy 0.9590643274853801
# macro-precision: 0.9648306377784559
# macro-recall: 0.9477513227513228
# macro-f1: 0.955237276092891
# <ipython-input-172-7b4403333ea4>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   model.fit(Xtrain,ytrain)

# %% [markdown]
# ### Matriz de confusión

# %%
TargetNames= ["0","1"] 
from sklearn.metrics import confusion_matrix
m = confusion_matrix(ytest, ypred).astype(float)

total = np.sum(m,axis=1)
print('total:',total)

for r,ren in enumerate(m):
    m[r,:] = m[r,:] / total[r]

m = np.round(m,2)
df = pandas.DataFrame(m,columns=TargetNames,index=TargetNames)
df
# Out:
# total: [ 63. 108.]
#       0     1
# 0  0.90  0.10
# 1  0.01  0.99

# %% [markdown]
# # Modelo Nearest Centroid

# %% [markdown]
# ## Separamos datos en entrenamiento y test

# %%
model = NearestCentroid()
model.fit(Xtrain,ytrain)
ypred = model.predict(Xtest)
print('accuracy',accuracy_score(ytest,ypred))
print('macro-precision:',precision_score(ytest,ypred,average='macro'))
print('macro-recall:',recall_score(ytest,ypred,average='macro'))
print('macro-f1:',f1_score(ytest,ypred,average='macro'))
# Out:
# accuracy 0.9181286549707602
# macro-precision: 0.9426229508196722
# macro-recall: 0.8888888888888888
# macro-f1: 0.9070652173913043
# C:\Users\oscar\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# ### Matriz de confusión

# %%
TargetNames= ["0","1"] 
from sklearn.metrics import confusion_matrix
m = confusion_matrix(ytest, ypred).astype(float)

total = np.sum(m,axis=1)
print('total:',total)

for r,ren in enumerate(m):
    m[r,:] = m[r,:] / total[r]

m = np.round(m,2)
df = pandas.DataFrame(m,columns=TargetNames,index=TargetNames)
df
# Out:
# total: [ 63. 108.]
#       0     1
# 0  0.78  0.22
# 1  0.00  1.00
